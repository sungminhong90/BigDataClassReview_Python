# %%
import platform

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,6]

# %%
import seaborn as sns
sns.set()

font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
df = pd.read_excel("./data/project/EV_growth_0912.xlsx")

# %%
df.head()
# Out:
#    year    vehicle
# 0  2019  35113.086
# 1  2020  40804.400
# 2  2021  46495.000
# 3  2022  52185.030
# 4  2023  57874.062

# %%
df_index = pd.Series(df['vehicle'].values, index=df['year'].values)
df_index
# Out:
# 2019     35113.086
# 2020     40804.400
# 2021     46495.000
# 2022     52185.030
# 2023     57874.062
# 2024     63562.477
# 2025     69250.664
# 2026     74938.670
# 2027     80626.620
# 2028     86314.570
# 2029     92002.460
# 2030     97690.320
# 2031    103378.180
# 2032    109066.020
# 2033    114753.860
# 2034    120441.710
# 2035    126129.540
# 2036    131817.400
# 2037    137505.250
# 2038    143193.110
# 2039    148880.950
# 2040    154568.800
# 2041    160256.640
# 2042    165944.480
# 2043    171632.330
# 2044    177320.140
# 2045    183008.020
# 2046    188695.830
# 2047    194383.700
# 2048    200071.600
# dtype: float64

# %%
df_index.values
# Out:
# array([ 35113.086,  40804.4  ,  46495.   ,  52185.03 ,  57874.062,
#         63562.477,  69250.664,  74938.67 ,  80626.62 ,  86314.57 ,
#         92002.46 ,  97690.32 , 103378.18 , 109066.02 , 114753.86 ,
#        120441.71 , 126129.54 , 131817.4  , 137505.25 , 143193.11 ,
#        148880.95 , 154568.8  , 160256.64 , 165944.48 , 171632.33 ,
#        177320.14 , 183008.02 , 188695.83 , 194383.7  , 200071.6  ])

# %%
df_index.values[2]
# Out:
# 46495.0

# %%
type(df_index.values[2])
# Out:
# numpy.float64

# %%
df_index.plot(kind='barh');

# %%
plt.rcParams["figure.figsize"] = [15, 5]
df_index.plot(kind='bar', title='전기차 시장 증가 예상', color = 'g');
